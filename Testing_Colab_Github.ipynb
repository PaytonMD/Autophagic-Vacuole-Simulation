# %% [markdown]
# <a href="https://colab.research.google.com/github/PaytonMD/Autophagic-Vacuole-Simulation/blob/master/Testing_Colab_Github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testing CoLaboratory/github link
#
# Making a minor edit just now.

# %%
import numpy as  np
import matplotlib.pyplot as plt

# %%
# The newer, more-preferred, object-oriented / API style,
# rather than using the older pyplot interface;
# see https://matplotlib.org/stable/tutorials/introductory/lifecycle.html
# Code from https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y,'.')
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')
